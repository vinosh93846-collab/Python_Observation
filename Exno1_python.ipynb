# %% [markdown]
# <a href="https://colab.research.google.com/github/vinosh93846-collab/Python_Observation/blob/main/Exno1_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
options=['stone','paper','scissors']
point_h=0
point_c=0
round=int(input("how many rounds you wanna play??"))
rounds=0
while round>rounds:
    human_player=input("Enter your preference...").lower()
    print('Your response is...',human_player)
    comp=random.choice(options);
    print('The computer response is...',comp)
    if human_player==comp:
        print("It's a tie")
        point_h+=1;
        point_c+=1
    elif human_player!=comp:
        if(human_player=="stone" and comp=="scissors") or (human_player=="paper" and comp=="stone")or(human_player=="scissors" and comp=="paper"):
            point_h+=1
        else:
            point_c+=1
    rounds+=1
else:
     print("Your total score:",point_h)
     print("your computer score:",point_c)
# Out:
# how many rounds you wanna play??2
# Enter your preference...stone
# Your response is... stone
# The computer response is... paper
# Enter your preference...paper
# Your response is... paper
# The computer response is... stone
# Your total score: 1
# your computer score: 1
